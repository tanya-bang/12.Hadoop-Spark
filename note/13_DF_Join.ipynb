# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from datetime import date, datetime
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
left_df = spark.createDataFrame([
    ('김철수', 15, date(2022,7,22)),
    ('이제동', 20, date(2021,7,22)),
    ('김명운', 25, date(2020,7,22)),
    ('임요환', 25, date(2020,7,22))
],schema='name string, age int, birth date')



right_df = spark.createDataFrame([
    ('김철수', 100),
    ('이제동', 90),
    ('김명운', 80),
    ('홍진호', 80)
],schema='name string, score int')

# %% [markdown]
# ## Join

# %% [markdown]
# ![image.png](attachment:35178f87-792e-4d7a-9109-68991e623904.png)

# %% [markdown]
# ### join 종류
#
# - inner join
# - left outer join
# - right outer join
# - full outer join

# %%
# default : inner join

# %%
# left join 

# right join

# %%
# outer join

# %%
# leftsemi join  leftsemi == semi
# 교집합, 데이터 결합 x

# %%
# leftanti join  leftanti == anti
# 차집합
